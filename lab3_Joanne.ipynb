# %%
with open ("romeoandjuliet.txt", "r") as randj:
    data= randj.read().lower()    # read the text file in strings as lowercase
def word_unique(x):               # define a function: word_unique, set input as x
    words= x.split()              # split up the words in the text
    words_set= set(words)         # set serves for picking out the unique words in the text
    return words_set              # define output as words_set

wording= [w.replace(" " ,"").replace("'" ,"").replace(";","").replace(",","").replace("(","").replace(")","").replace(".","").replace("[","").replace("!","").replace("?","").replace("]","").replace("\ ","").replace("-","") for w in word_unique(data)] 
        # use replace to slice out the unwanted punctuations of the running function. 
print(wording)
        # print out the split results in a list
# Out:
# ['jaws', 'osier', 'merciful', 'misbhavd', 'woful', 'maria', 'bleeds', 'talkd', 'bit', 'beauty', 'fairies', 'cell', 'romeo', 'yea', 'post', 'piece', 'alack', 'blest', 'it', 'canker', 'him', 'pens', 'ears', 'heavens', 'substance', 'makes', 'broad', 'knit', 'meanest', 'taen', 'bridal', 'ground', 'crutch', 'madman', 'masters', 'high', 'foe', 'mother', 'suit', 'one', 'deathdarting', 'bigger', 'food', 'false', 'art', 'they', 'bound', 'direful', 'he', 'blood', 'ordained', 'mad', 'distraught', 'now', 'look', 'fell', 'end', 'shop', 'vice', 'fiddlestick', 'respects', 'fight', 'honour', 'prevent', 'privy', 'further', 'torch', 'wild', 'aside', 'capulet', 'spoke', 'dear', 'piercing', 'stay', 'crutch', 'taste', 'scratch', 'friend', 'same', 'trembles', 'endite', 'tybalt', 'today', 'had', 'life', 'behests', 'slaughtred', 'envious', 'trucklebed', 'account', 'watchmen', 'fortunes', 'dark', 'unhappy', 'gossip', 'smallest', 'wine', 'rest', 'son', 'begone', 'veronas', 'kindreds', 'merrily', 'early', 'hel
# ...

# %% [markdown]
# ### 1. Split out words into a list
# In the first part, we read out the text file "Romeo and Juliet" first into python converting it into string characters.
#
# Then, do a function that which the opened file served as the input. The function uses split() to split out the words in the text. set() is used to pick out the unique words. Return the results as the function output.
#
# In order to further slice out the punctuations, a list is created and use replace the desired punctuations into nothing (""). By this way all unwanted punctuations will be sliced off and print out in a list.

# %%
Dictionary={}                      # define a dictionary
for i in wording:
    word_count= data.count(i)      # count out the items for each unique key
    if word_count > 0:             # use an if statement to aviod storing repetitive counts of 0
        Dictionary[i] = word_count       
        # convert the list into a dictionary with unique word as keys and corresponding word counting as values
        print("Count is " + str(word_count) + " for " + i + ".")
        # print out the counts for each unique word.
# Out:
# Count is 1 for jaws.
# Count is 1 for osier.
# Count is 2 for merciful.
# Count is 7 for woful.
# Count is 1 for maria.
# Count is 1 for bleeds.
# Count is 16 for bit.
# Count is 13 for beauty.
# Count is 2 for fairies.
# Count is 20 for cell.
# Count is 156 for romeo.
# Count is 19 for yea.
# Count is 5 for post.
# Count is 3 for piece.
# Count is 11 for alack.
# Count is 3 for blest.
# Count is 824 for it.
# Count is 1 for canker.
# Count is 110 for him.
# Count is 3 for pens.
# Count is 46 for ears.
# Count is 4 for heavens.
# Count is 3 for substance.
# Count is 12 for makes.
# Count is 8 for broad.
# Count is 1 for knit.
# Count is 1 for meanest.
# Count is 3 for bridal.
# Count is 10 for ground.
# Count is 2 for crutch.
# Count is 3 for madman.
# Count is 1 for masters.
# Count is 12 for high.
# Count is 7 for foe.
# Count is 32 for mother.
# Count is 4 for suit.
# Count is 179 for one.
# Count is 2 for bigger.
# Count is 3 for food.
# Count is 3 for false.
# ...

# %% [markdown]
# ### 2. Find out the word counts for each unique word and put them into a dictionary
# After making the unique words into a list. We need to create a dictionary in which the keys are unique words and the values are the number of times that word appears in the play. Use a for loop to run through each unique word in the list, and do a word count. Use am if statement to avoid storing counts of 0. Then store these values into the dictionary and print out the counts.

# %%
print(Dictionary.keys(),Dictionary.values())
# Out:
# dict_keys(['jaws', 'osier', 'merciful', 'woful', 'maria', 'bleeds', 'bit', 'beauty', 'fairies', 'cell', 'romeo', 'yea', 'post', 'piece', 'alack', 'blest', 'it', 'canker', 'him', 'pens', 'ears', 'heavens', 'substance', 'makes', 'broad', 'knit', 'meanest', 'bridal', 'ground', 'crutch', 'madman', 'masters', 'high', 'foe', 'mother', 'suit', 'one', 'bigger', 'food', 'false', 'art', 'they', 'bound', 'direful', 'he', 'blood', 'ordained', 'mad', 'distraught', 'now', 'look', 'fell', 'end', 'shop', 'vice', 'fiddlestick', 'respects', 'fight', 'honour', 'prevent', 'privy', 'further', 'torch', 'wild', 'aside', 'capulet', 'spoke', 'dear', 'piercing', 'stay', 'taste', 'scratch', 'friend', 'same', 'trembles', 'endite', 'tybalt', 'had', 'life', 'behests', 'envious', 'account', 'watchmen', 'fortunes', 'dark', 'unhappy', 'gossip', 'smallest', 'wine', 'rest', 'son', 'begone', 'merrily', 'early', 'hell', 'forgot', 'excels', 'stream', 'seen', 'hereabouts', 'fellow', 'other', 'wail', 'see', 'appear', 'bout
# ...

# %% [markdown]
# ### 3. Printing out the dictionary with keys and values
# This prints out the whole dictionary with the unique words as keys and their corresponding word counts as assigned values.

# %%
# %matplotlib inline
import matplotlib.pyplot as plt    # import matplotlib tools to draw out the bar plot
width= 20                          # define the width
p1 = plt.bar(range(len(Dictionary.keys())), Dictionary.values(), width)
plt.title('Word Count in Romeo and Juliet')            # define the title of the plot
plt.ylabel("Word Count")            # define y-axis
plt.xlabel("Unique Words")         # define x-axis

plt.show()                         # output= bar plot showing the occurence of each unique key

# %% [markdown]
# ### 4. Graphing out the word counts into a histogram (bar plot)
# In this part we are plotting a bar graph that shows the frequency with which each word appears. The matplotlib is imported in order to use for plotting the bar graph. For plotting out the values, the bar plot uses the length of dictionary (number of items in the dictionary) as range of x-axis, and y-axis serves for the dictionary values (the word counts corresponding to each unique word). The number on x-axis refers to number orders in the dictionary referring to the unique words.

# %%
print("10 Most frequent words:")
for i in Dictionary.keys():                  # finding the 10 most frequent words
    if Dictionary.get(i) == 9470:
        print(i + ":9470")
for i in Dictionary.keys():        
    if Dictionary.get(i) == 8515:
        print(i + ":8515")
for i in Dictionary.keys():        
    if Dictionary.get(i) == 8079:
        print(i + ":8079")
for i in Dictionary.keys():        
    if Dictionary.get(i) == 6667:
        print(i + ":6667")
for i in Dictionary.keys():        
    if Dictionary.get(i) == 6437:
        print(i + ":6437")
for i in Dictionary.keys():        
    if Dictionary.get(i) == 3417:
        print(i + ":3417")
for i in Dictionary.keys():        
    if Dictionary.get(i) == 3366:
        print(i + ":3366")
for i in Dictionary.keys():        
    if Dictionary.get(i) == 2331:
        print(i + ":2331")
for i in Dictionary.keys():        
    if Dictionary.get(i) == 1569:
        print(i + ":1569")
for i in Dictionary.keys():        
    if Dictionary.get(i) == 1360:
        print(i + ":1360")

print("Words that appear once:")        # finding words that appear only once
for i in Dictionary.keys():        
    if Dictionary.get(i) == 1:
        print(i + ", ")
# Out:
# 10 Most frequent words:
# t:9470
# o:8515
# a:8079
# i:6667
# r:6437
# m:3417
# th:3366
# he:2331
# an:1569
# in:1360
# Words that appear once:
# jaws,
# osier,
# maria,
# bleeds,
# canker,
# knit,
# meanest,
# masters,
# direful,
# ordained,
# distraught,
# fiddlestick,
# respects,
# privy,
# piercing,
# trembles,
# endite,
# behests,
# watchmen,
# fortunes,
# smallest,
# wine,
# begone,
# merrily,
# stream,
# hereabouts,
# me:,
# assure,
# quivering,
# fairest,
# containing,
# tormented,
# aloft,
# trumpet,
# learning,
# hurry,
# jaunce,
# lucio,
# pieces,
# tragedy,
# penury,
# crystal,
# digressing,
# demand,
# eight,
# expire,
# looking,
# forsooth,
# jests,
# resolution,
# ambling,
# unrest,
# stifled,
# caitiff,
# effeminate,
# youngest,
# napkins,
# affliction,
# suspecting,
# taker,
# baleful,
# overwhelming,
# holding,
# numbers,
# james,
# laura,
# already:,
# bauble,
# dispraise,
# unsubstantial,
# traffic,
# puts,
# honest:,
# state:,
# unruly,
# elflocks,
# tortoise,
# ...

# %% [markdown]
# ### General Analysis
# According to the list of counts for each unique word and the word count histogram, we can decide the 10 most frequent appearing words by looking over the dictionary list for the ten largest values and checked them over the histogram. And find the corresponding keys to the values by doing a for loop and if statement. The 10 most frequent unique words are:
# 1. t: 9470
# 2. o: 8515
# 3. a: 8079
# 4. i: 6667
# 5. r: 6437
# 6. m: 3417
# 7. th: 3366
# 8. he: 2331
# 9. an: 1569
# 10. in: 1360
#
#
# - Notice that the 10 most frequent words are single alphabets or conjunction and adposition and article, which makes sense that these are will appear a lot of times in the text for their needs compare to other nouns, verbs and so on.
#
# For the least appearing words, they are the words that appear only once, we can also find the keys by testing if the count== 1.The words are listed above. Those are words that are nouns, verbs, adjective and adverbs that refer to specific things.
