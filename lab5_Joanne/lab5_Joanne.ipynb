# %% [markdown]
# ## Grabbing the sequences from the paper
# We first obtain the four riboswitch seqeucnes for YES-1, NOT-1, AND-1 and OR-1 from the paper given.
#
# ## For	each riboswitch, produce a clear list that contains	the	following information:
# (1)	riboswitch name
#
# (2)	start and end coordinates of OBS-1 (blue region)
#
# (3)	start and end coordinates of OBS-2 (blue region, only applicable to	AND-1 and OR-1)
#
# (4)	start and end coordinates of the two red regions
#
#
# ### YES-1
#
# yes_seq =
# GGGCGACCCUGAUGAGCUUGAGUUUAGCUCGUCACUGUCCAGGUUCAAUCAGGCGAAACGGUGAAAGCCGUAGGUUGCCC
#
# (1)riboswitch name: YES-1
#
# (2)start and end coordinates of OBS: 26-47
#
# (4)Red regions: 16-21, 49-54
#
#
# ### NOT-1
#
# not_seq = GGCAGGUACAUACAGCUGAUGAGUCCCAAAUAGGACGAAACGCGACACACACCACUAAACCGUGCAGUGUUUUGCGUCCUGUAUUCCACUGC
#
# (1)riboswitch name: NOT-1
#
# (2)start and end coordinates of OBS: 44-66
#
# (3)Red regions: 40-43, 74-77
#
#
# ### AND-1
#
# and_seq = GGGCGACCCUGAUGAGCUUGGUUUAGUAUUUACAGCUCCAUACAUGAGGUGUUAUCCCUAUGCAAGUUCGAUCAGGCGAAACGGUGAAAGCCGUAGGUUGCCCAGAGACAAU
#
# (1)riboswitch name: AND-1
#
# (2)start and end coordinates of OBS1: 30-45
#
# (3)start and end coordinates of OBS2: 49-64
#
# (4)Red regions: 16-23, 70-77
#
#
# ### OR-1
#
# or_seq = GGGCGACCCCUGAUGGCUUGGUUGAGUAUUUACAGCUCCAUAUACAUGAGGUGUUCUCCCUACGCAAGUUCGAUCAGGCGAAACGGUGAAAGCCGUAGGUUGCCC
#
# (1)riboswitch name: OR-1
#
# (2)start and end coordinates of OBS1: 27-46
#
# (3)start and end coordinates of OBS2: 47-66
#
# (4)Red regions: 16-26, 67-77

# %% [markdown]
# ### Write a routine to fold RNA
#
# To run the RNAfold in the terminal by the following command:
# 1. RNAfold     (calling out the tool to fold the RNA)
# 2. "copy and paste in the desired sequence"
# 3. use @ to terminate the stdin
# 4. RNAplot     (calling the tool to plot out the folded sequence)
# 5. use @ to terminate again
#
# This gives a rna.ps file with the folded RNA!!
#
# In order to subprocess the four sequences together in python, use the following the function:
# 1. import subprocess
# 2. put the four sequences into a "list" named seqs
# 3. run the subprocess and call the tool RNAfold to process,
#    this function will run the RNAfold four times for each sequences in seqs
# 4. stdout is the output, and stederr is how things work out in the terminal
#
# This gives four rna.ps files with the folded RNA!!

# %%
import subprocess

seqs= \
""">seq1
GGGCGACCCUGAUGAGCUUGAGUUUAGCUCGUCACUGUCCAGGUUCAAUCAGGCGAAACGGUGAAAGCCGUAGGUUGCCC
>seq2
GGCAGGUACAUACAGCUGAUGAGUCCCAAAUAGGACGAAACGCGACACACACCACUAAACCGUGCAGUGUUUUGCGUCCUGUAUUCCACUGC
>seq3
GGGCGACCCUGAUGAGCUUGGUUUAGUAUUUACAGCUCCAUACAUGAGGUGUUAUCCCUAUGCAAGUUCGAUCAGGCGAAACGGUGAAAGCCGUAGGUUGCCCAGAGACAAU
>seq4
GGGCGACCCCUGAUGGCUUGGUUGAGUAUUUACAGCUCCAUAUACAUGAGGUGUUCUCCCUACGCAAGUUCGAUCAGGCGAAACGGUGAAAGCCGUAGGUUGCCC
"""

p = subprocess.run(['RNAfold'],
                    input = bytes(seqs, 'ascii'),
                   stdout = subprocess.PIPE,   
                   stderr=subprocess.PIPE)    


print("***And this would have been in your output file***")
print(p.stdout.decode())
# Out:
# ***And this would have been in your output file***
# >seq1
# GGGCGACCCUGAUGAGCUUGAGUUUAGCUCGUCACUGUCCAGGUUCAAUCAGGCGAAACGGUGAAAGCCGUAGGUUGCCC
# ((((((((.(((((((((.......))))))))).((.((.(((...))).))))..(((((....))))).)))))))) (-33.00)
# >seq2
# GGCAGGUACAUACAGCUGAUGAGUCCCAAAUAGGACGAAACGCGACACACACCACUAAACCGUGCAGUGUUUUGCGUCCUGUAUUCCACUGC
# .((((....((((((.......((((......))))...((((((.((((..(((......)))..)))).)))))).))))))....)))) (-28.10)
# >seq3
# GGGCGACCCUGAUGAGCUUGGUUUAGUAUUUACAGCUCCAUACAUGAGGUGUUAUCCCUAUGCAAGUUCGAUCAGGCGAAACGGUGAAAGCCGUAGGUUGCCCAGAGACAAU
# ((((((((((((((((((((...(((.....(((.(((.......))).))).....)))..))))))).))))).....(((((....))))).))))))))......... (-42.10)
# >seq4
# GGGCGACCCCUGAUGGCUUGGUUGAGUAUUUACAGCUCCAUAUACAUGAGGUGUUCUCCCUACGCAAGUUCGAUCAGGCGAAACGGUGAAAGCCGUAGGUUGCCC
# ((((((((((((((((((((((.(((.....(((.(((.........))).))).)))...)).))))))..))))))....(((((....))))).)))))))) (-37.50)

# %% [markdown]
# #### The following plots out the four RNA folded structure by importing matplotlib in order to plot. (larger images can be found under the same folder lab5_Joanne for each plot)
#
# #### Matplotlib image is used in this case to display the image we have.
#
# #### Compare the images with the publication's

# %% [markdown]
# ## YES-1

# %%
# %matplotlib inline
import matplotlib.pyplot as plt     
import matplotlib.image as mpimg
img=mpimg.imread("YES-1.png")
imgplot=plt.imshow(img)
plt.title('YES-1')
plt.show()

# %% [markdown]
# ## NOT-1

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
img=mpimg.imread("NOT-1.png")
imgplot=plt.imshow(img)
plt.title('NOT-1') 
plt.show()

# %% [markdown]
# ## AND-1

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
img=mpimg.imread("AND-1.png")
imgplot=plt.imshow(img)
plt.title('AND-1') 
plt.show()

# %% [markdown]
# ## OR-1

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
img=mpimg.imread("OR-1.png")
imgplot=plt.imshow(img)
plt.title('OR-1') 
plt.show()

# %% [markdown]
# #### Analysis
# For YES-1, the red regions are not bound. Comparing with the publication's YES-1, the image I generated have an addition stem loop. The temperature used in both case (paper and default) are 37 degrees. One possible reason is that the author in publication had mentioned that this structure "has the potential to form several alternative secondary structures" that are thermodynamically less stable in their inactive state. So this should be common.
#
# For NOT-1,the red regions are bound, producing that self-cleaving structure. Comparing witht the publications' NOT-1, the folded structures are very similar. With a small stem loop more distinguishable in the picuture I generate (in the paper that small stem loop is somehow a little "fused" with another stem loop).
#
# For AND-1, the red regions are not bound. Comparing with the publications, the folded structures are the same.
#
# For OR-1, the red regions are not bound. Comparing with the publications, the folded structures are the same.

# %% [markdown]
# ## Stimulating the YES-1, NOT-1, AND-1 and OR-1 OBS bindings
# - we first generate files of constraints, in text files with sequences and another line indicating which position to be constrainted or not (. and x)
# - Run the RNAfold for each riboswitch constrainted on the OBS region with the command "RNAfold -C file.name"
# - This generates the folded RNA structure with OBS sites being constrainted/bound.
# - For YES-1 and NOT-1 there is only two conditions: true= constraint, false= not constraint.
# - For AND-1 and OR-1 there would be four conditions in total: True,True= both OBS being constraint, True,False= only first site constraint, False,True= only second site constraint, False,False= none of the site constraint
#
# #### In the plot below, that giant circle loop refers to the sites that are constraint= unpaired.
# #### larger images can be found under the same folder lab5_Joanne for each plot)

# %% [markdown]
# ## YES-1 OBS constraint (position 26-47)

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
img=mpimg.imread("YES_constraint.png")
imgplot=plt.imshow(img)
plt.title('YES-1 OBS constraint') 
plt.show()

# %% [markdown]
# For YES-1 constraint, it can be seen that the red regions are clearly paired up. It looks like the same self-cleaving structure as shown in the paper.

# %% [markdown]
# ## NOT-1 OBS constraint (position 44-66)

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
img=mpimg.imread("NOT_constraint.png")
imgplot=plt.imshow(img)
plt.title('NOT-1 OBS constraint') 
plt.show()

# %% [markdown]
# For NOT-1 constraint, it can be seen that the red regions are not paired up anymore. Thus not producing a self-cleaving structure, which is the same as indicated in the paper.

# %% [markdown]
# ## AND-1 constraint on the first OBS (position 30-45)

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
img=mpimg.imread("AND_constraint_firstOBS.png")
imgplot=plt.imshow(img)
plt.title('AND-1 constraint on the first OBS') 
plt.show()

# %% [markdown]
# ## AND-1 constraint on the second OBS (position 49-64)

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
img=mpimg.imread("AND_constraint_secondOBS.png")
imgplot=plt.imshow(img)
plt.title('AND-1 constraint on the second OBS') 
plt.show()

# %% [markdown]
# ## AND-1 constraint on both OBS (position 30-45, 49-64)

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
img=mpimg.imread("AND_constraint_bothOBS.png")
imgplot=plt.imshow(img)
plt.title('AND-1 constraint on both OBS') 
plt.show()

# %% [markdown]
# ## OR-1 constraint on the first OBS (position 27-46)

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
img=mpimg.imread("OR_constraint_firstOBS.png")
imgplot=plt.imshow(img)
plt.title('OR-1 constraint on the first OBS') 
plt.show()

# %% [markdown]
# ## OR-1 constraint on the second OBS (position 47-66)

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
img=mpimg.imread("OR_constraint_secondOBS.png")
imgplot=plt.imshow(img)
plt.title('OR-1 constraint on the second OBS') 
plt.show()

# %% [markdown]
# ## OR-1 constraint on both OBS (position 47-66)

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
img=mpimg.imread("OR_constraint_bothOBS.png")
imgplot=plt.imshow(img)
plt.title('OR-1 constraint on both OBS') 
plt.show()

# %% [markdown]
# ### Generate a	truth table	for	the	AND-1 and the OR-1 riboswitches	based on results

# %%
print("***Determine whether the red regions pair with each other***\n")
print("            And         OR        ")
print("----------------------------------")
print("first OBS   False       True      ")

print("second OBS  False       True      ")

print("both OBS    True        True      ")
# Out:
# ***Determine whether the red regions pair with each other***
#
#             And         OR
# ----------------------------------
# first OBS   False       True
# second OBS  False       True
# both OBS    True        True

# %% [markdown]
# Acccording to my results, in AND-1, only if both OBS are constraint would the red regions paired to each other. For OR-1, any one of OBS is constraint would result red regions to be paired (which this makes why the three constraint for OR-1 above RNA folded structure look so similar).
#
# Therefore, the AND-1 and OR-1 do work as the paper claims.
