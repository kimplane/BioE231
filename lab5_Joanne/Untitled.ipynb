# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
img=mpimg.imread("YES-1.png")
imgplot=plt.imshow(img)
plt.title('YES-1') 
plt.show()

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
img=mpimg.imread("YES-1.png")
plt.imshow(img)

# %%
# %matplotlib inline
from pylab import imread, subplot, imshow, show
import matplotlib.pyplot as plt
image=imread("YES-1.png")
plt.imshow(image)
